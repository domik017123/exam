# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/youtube/youtube.csv",index_col=0)
df.head()
# Out:
#                                                title             channelTitle  \
# 0                                          [신병] 물자창고                      장삐쭈
# 1   RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV  RAIN's Official Channel
# 2       2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.              서울시 · Seoul
# 3                                       고기남자의 칠면조 파티             고기남자 MeatMan
# 4  골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...                    스브스밥집
#
#    categoryId  view_count  likes  dislikes  comment_count  \
# 0          23     1893473  38249       730           8595
# 1          10     2600864      0         0          20129
# 2          29      347049   3564       120            178
# 3          26      528458  15372       280           3470
# 4          24      494904   3918       111           3142
#
#                   channelId trending_date2
# 0  UChbE5OZQ6dRHECsX0tEPEZQ     2021-01-01
# 1  UCxXgIeE5hxWxHG6dz9Scg2w     2021-01-01
# ...

# %%
result=df.channelTitle.value_counts().sort_values(ascending=False)
result.head(10).index.to_list()
# Out:
# ['짤툰',
#  '파뿌리',
#  'SPOTV',
#  '런닝맨 - 스브스 공식 채널',
#  '엠뚜루마뚜루 : MBC 공식 종합 채널',
#  '장삐쭈',
#  'BANGTANTV',
#  '채널 십오야',
#  '이과장',
#  '총몇명']

# %%
result=df.loc[df.dislikes>df.likes].channelTitle.sort_values()
result=result.unique()

print(len(result))
# Out:
# 14

# %%
result=df[['channelId','channelTitle']].drop_duplicates().groupby('channelId').size()
result2=result.loc[result>1]
len(result2)
# Out:
# 71

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60399 entries, 0 to 60398
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           60399 non-null  object
#  1   channelTitle    60399 non-null  object
#  2   categoryId      60399 non-null  int64
#  3   view_count      60399 non-null  int64
#  4   likes           60399 non-null  int64
#  5   dislikes        60399 non-null  int64
#  6   comment_count   60399 non-null  int64
#  7   channelId       60399 non-null  object
#  8   trending_date2  60399 non-null  object
# dtypes: int64(5), object(4)
# memory usage: 4.6+ MB

# %%
df['trending_date']=pd.to_datetime(df.trending_date2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60399 entries, 0 to 60398
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           60399 non-null  object
#  1   channelTitle    60399 non-null  object
#  2   categoryId      60399 non-null  int64
#  3   view_count      60399 non-null  int64
#  4   likes           60399 non-null  int64
#  5   dislikes        60399 non-null  int64
#  6   comment_count   60399 non-null  int64
#  7   channelId       60399 non-null  object
#  8   trending_date2  60399 non-null  object
#  9   trending_date   60399 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(5), object(4)
# memory usage: 5.1+ MB

# %%
import datetime
df['weekDay']=df['trending_date'].dt.day_name()
df['weekDay'].head()
# Out:
# 0    Friday
# 1    Friday
# 2    Friday
# 3    Friday
# 4    Friday
# Name: weekDay, dtype: object

# %%
result=df.loc[df.weekDay=='Sunday']
result=result.categoryId.value_counts().sort_values(ascending=False)
result.head(1).index[0]
# Out:
# 24

# %%
result=df.pivot_table(index='categoryId',columns='weekDay',aggfunc='size')
result
# Out:
# weekDay     Friday  Monday  Saturday  Sunday  Thursday  Tuesday  Wednesday
# categoryId
# 1              243     263       255     274       246      257        234
# 2              120     105       119      99       128      119        129
# 10             833     837       776     830       890      894        917
# 15             187     215       198     217       207      208        207
# 17             633     668       592     636       682      708        706
# 19              90      92        87      91        92       89         85
# 20             283     298       296     289       282      285        291
# 22            1288    1373      1289    1337      1341     1375       1333
# 23             568     594       570     556       560      569        566
# 24            2976    3148      3066    3096      2954     3084       3090
# 25             444     453       422     437       470      452        468
# ...

# %%
df.head()
# Out:
#                                                title             channelTitle  \
# 0                                          [신병] 물자창고                      장삐쭈
# 1   RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV  RAIN's Official Channel
# 2       2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.              서울시 · Seoul
# 3                                       고기남자의 칠면조 파티             고기남자 MeatMan
# 4  골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...                    스브스밥집
#
#    categoryId  view_count  likes  dislikes  comment_count  \
# 0          23     1893473  38249       730           8595
# 1          10     2600864      0         0          20129
# 2          29      347049   3564       120            178
# 3          26      528458  15372       280           3470
# 4          24      494904   3918       111           3142
#
#                   channelId trending_date2 trending_date weekDay
# 0  UChbE5OZQ6dRHECsX0tEPEZQ     2021-01-01    2021-01-01  Friday
# ...

# %%
result=df.loc[df.view_count!=0].copy()
result.loc[:,'ratio']=result['comment_count']/result['view_count']
result=result.sort_values('ratio',ascending=False)
print(result.iloc[0].title)
# Out:
# 60분 동안 댓글이 달리지 않으면, 영상이 삭제됩니다. (챌린지)

# %%
result=result.loc[result.ratio!=0]
result=result.sort_values('ratio')

print(result.iloc[0].title)
# Out:
# Join the BTS #PermissiontoDance Challenge only on YouTube #Shorts

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/youtube/youtube.csv",index_col=0)
result=df.loc[(df.likes!=0) & df.dislikes!=0 ]
result2=result.copy()
result2['ratio']=result.dislikes/result.likes
result2=result2.sort_values('ratio')
print(result2.iloc[0].title)
# Out:
# [줌터뷰] *최초공개* 사부작즈🐰🐶의 비공식 이름은 아이라인즈? 꿀조합 티키타카 가득한 NCT 127 도영&정우의 줌터뷰

# %%
result=df.channelTitle.value_counts().sort_values(ascending=False)
# result.head()
print(result.head(1).index[0])
# Out:
# 짤툰

# %%
result=df[['title','channelId']].value_counts()
result=result.loc[result >= 20]
len(result)
# Out:
# 40

# %%
df.head()
# Out:
#                                                title             channelTitle  \
# 0                                          [신병] 물자창고                      장삐쭈
# 1   RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV  RAIN's Official Channel
# 2       2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.              서울시 · Seoul
# 3                                       고기남자의 칠면조 파티             고기남자 MeatMan
# 4  골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...                    스브스밥집
#
#    categoryId  view_count  likes  dislikes  comment_count  \
# 0          23     1893473  38249       730           8595
# 1          10     2600864      0         0          20129
# 2          29      347049   3564       120            178
# 3          26      528458  15372       280           3470
# 4          24      494904   3918       111           3142
#
#                   channelId trending_date2
# 0  UChbE5OZQ6dRHECsX0tEPEZQ     2021-01-01
# 1  UCxXgIeE5hxWxHG6dz9Scg2w     2021-01-01
# ...
